# %%
import requests
import json

# API konstanter
BASE_URL = "http://localhost:5088"
HEADERS = {"Content-Type": "application/json"}

# %%
# Funktion til at oprette en ny customer
def create_customer():
    customer_data = {
        "name": "Svend CSharpsen",
        "type": "privat",
        "phone": "12345678",
        "address": "Kundevej 1",
        "email": "kunde@example.com"
    }
    response = requests.post(f"{BASE_URL}/createcustomer", json=customer_data, headers=HEADERS)
    return response.json()

# Funktion til at oprette en ny trailer
def create_trailer():
    trailer_data = {
        "name": "zteffanos Test Trailer",
        "year": 2023,
        "brand": "Zimula Trailerz",
        "weight": 150,
        "totalWeight": 750,
        "carryWeight": 600,
        "type": "crypto",
        "licensePlate": "TT 12345",
        "dayPrice": 200,
        "length": 250,
        "width": 125
    }
    response = requests.post(f"{BASE_URL}/createtrailer", json=trailer_data, headers=HEADERS)
    return response.json()

# Funktion til at oprette en ny booking
def create_booking(customer_id, trailer_id):
    booking_data = {
        "bookedFrom": "2023-11-08T10:00:00",
        "bookedTo": "2023-11-10T10:00:00",
        "customerId": customer_id,
        "trailerId": trailer_id
    }
    response = requests.post(f"{BASE_URL}/createbooking", json=booking_data, headers=HEADERS)
    return response.json()

# %%
# Funktion til at hente og printe data fra tabellerne
def fetch_and_print(endpoint):
    response = requests.get(f"{BASE_URL}/{endpoint}", headers=HEADERS)
    print(f"Data from {endpoint}:")
    print(json.dumps(response.json(),indent=2))

# %%
# Funktion til at slette en booking, customer og trailer
def delete_resource(endpoint, resource_id):
    response = requests.delete(f"{BASE_URL}/{endpoint}/{resource_id}", headers=HEADERS)
    return response.status_code

# %% [markdown]
# ---

# %%
# Fetch data
fetch_and_print('customers')
fetch_and_print('trailers')
fetch_and_print('bookings')
# Out:
# Data from customers:
# [
#   {
#     "name": "Jensens V\u00e6rksted",
#     "type": "Erhverv",
#     "phone": "32123456",
#     "address": "Industrihaven 4, 4000 Roskilde",
#     "email": " jensensvaerksted@example.dk"
#   },
#   {
#     "name": "Hanne Fogh",
#     "type": "Privat",
#     "phone": "29768594",
#     "address": "B\u00f8gevej 7, 8000 Aarhus",
#     "email": " hanne.fogh@example.com"
#   },
#   {
#     "name": "S\u00f8ndergaard Biler",
#     "type": "Erhverv",
#     "phone": "31475869",
#     "address": "Autovej 12, 6700 Esbjerg",
#     "email": "info@sondergaardbiler.dk"
#   },
#   {
#     "name": "Larsen B\u00e5dudlejning",
#     "type": "Erhverv",
#     "phone": "33890001",
#     "address": "Havnepladsen 22, 1058 K\u00f8benhavn",
#     "email": "b\u00e5dudlejning@larsen.dk"
#   },
#   {
#     "name": "Kirstens Blomster",
#     "type": "Erhverv",
#     "phone": "35678900",
#     "address": "Blomsterv\u00e6nget 3, 2300 K\u00f8benhavn S",
#     "email": "kirstensblomster@example.dk"
#   },
#   {
#     "name": "Anders og Co.",
#     "type": "Privat",
#     "phone": "40203040",
#     "address": "Skovbrynet 1, 3400 Hiller\u00f8d",
#     "email": "andersogco@example.com"
#   },
#   {
#     "name": "Peters Cykler",
#     "type": "Erhverv",
#     "phone": "45678910",
#     "address": "Pedalvej 5, 7100 Vejle",
#     "email": "peterscykler@example.dk"
#   },
#   {
#     "name": "Mette's Catering",
#     "type": "Erhverv",
#     "phone": "50607080",
#     "address": "Kokkegade 8, 5000 Odense",
#     "email": "mettescatering@example.com"
#   },
#   {
#     "name": "Oliver Nielsen",
#     "type": "Privat",
#     "phone": "27395061",
#     "address": "Hyttevej 10, 2840 Holte",
#     "email": "oliver.nielsen@example.com"
#   },
#   {
#     "name": "Lise Lotte",
#     "type": "Private",
#     "phone": "50555055",
#     "address": "Flyttevejen 2, 6000 Kolding",
#     "email": "lise-lotte@koldingborger.dk"
#   }
# ]
# Data from trailers:
# [
#   {
#     "name": "BRANFORD TRAILER 750KG",
#     "year": 2022,
#     "brand": "BRANFORD",
#     "weight": 110,
#     "totalWeight": 750,
#     "carryWeight": 640,
#     "type": "hobby",
#     "licensePlate": "TT 20800",
#     "dayPrice": 350,
#     "length": 195,
#     "width": 105
#   },
#   {
#     "name": "Nordisk Trailer Model 1000",
#     "year": 2021,
#     "brand": "Nordisk Trailer",
#     "weight": 130,
#     "totalWeight": 1000,
#     "carryWeight": 870,
#     "type": "bygge",
#     "licensePlate": "TT 20900",
#     "dayPrice": 400,
#     "length": 200,
#     "width": 120
#   },
#   {
#     "name": "Hermansen Cargo XL",
#     "year": 2020,
#     "brand": "Hermansen",
#     "weight": 160,
#     "totalWeight": 1300,
#     "carryWeight": 1140,
#     "type": "last",
#     "licensePlate": "TT 21000",
#     "dayPrice": 500,
#     "length": 250,
#     "width": 150
#   },
#   {
#     "name": "DanCargo Handyman",
#     "year": 2019,
#     "brand": "DanCargo",
#     "weight": 100,
#     "totalWeight": 600,
#     "carryWeight": 500,
#     "type": "hobby",
#     "licensePlate": "TT 21100",
#     "dayPrice": 300,
#     "length": 180,
#     "width": 90
#   },
#   {
#     "name": "Viking Trailers Strongman",
#     "year": 2018,
#     "brand": "Viking",
#     "weight": 145,
#     "totalWeight": 2000,
#     "carryWeight": 1855,
#     "type": "erhverv",
#     "licensePlate": "TT 21200",
#     "dayPrice": 700,
#     "length": 300,
#     "width": 160
#   },
#   {
#     "name": "Scandinavian Boat Carrier",
#     "year": 2022,
#     "brand": "Scandinavian",
#     "weight": 120,
#     "totalWeight": 1800,
#     "carryWeight": 1680,
#     "type": "b\u00e5d",
#     "licensePlate": "TT 21300",
#     "dayPrice": 600,
#     "length": 320,
#     "width": 180
#   },
#   {
#     "name": "\u00d8stergaard Multiuse XL",
#     "year": 2017,
#     "brand": "\u00d8stergaard",
#     "weight": 140,
#     "totalWeight": 750,
#     "carryWeight": 610,
#     "type": "multianvend",
#     "licensePlate": "TT 21400",
#     "dayPrice": 350,
#     "length": 195,
#     "width": 105
#   },
#   {
#     "name": "Carlsen Trailer Flexi",
#     "year": 2021,
#     "brand": "Carlsen",
#     "weight": 115,
#     "totalWeight": 825,
#     "carryWeight": 710,
#     "type": "universal",
#     "licensePlate": "TT 21500",
#     "dayPrice": 375,
#     "length": 190,
#     "width": 100
#   },
#   {
#     "name": "Haul Master Pro",
#     "year": 2019,
#     "brand": "Haul Master",
#     "weight": 150,
#     "totalWeight": 2500,
#     "carryWeight": 2350,
#     "type": "last",
#     "licensePlate": "TT 21600",
#     "dayPrice": 800,
#     "length": 340,
#     "width": 170
#   },
#   {
#     "name": "Dan Trailers Eco",
#     "year": 2023,
#     "brand": "Dan Trailers",
#     "weight": 90,
#     "totalWeight": 500,
#     "carryWeight": 410,
#     "type": "hobby",
#     "licensePlate": "TT 21700",
#     "dayPrice": 250,
#     "length": 160,
#     "width": 90
#   }
# ]
# Data from bookings:
# [
#   {
#     "bookedFrom": "2023-10-01T08:00:00",
#     "bookedTo": "2023-10-03T18:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 1,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-05T09:00:00",
#     "bookedTo": "2023-10-10T15:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 2,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-12T14:00:00",
#     "bookedTo": "2023-10-15T12:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 3,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-18T10:00:00",
#     "bookedTo": "2023-10-25T16:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 4,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-27T08:30:00",
#     "bookedTo": "2023-10-29T19:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 5,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-01T12:00:00",
#     "bookedTo": "2023-11-04T14:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 6,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-05T08:00:00",
#     "bookedTo": "2023-11-12T20:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 7,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-06T13:00:00",
#     "bookedTo": "2023-11-10T11:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 8,
#     "trailerId": 2
#   }
# ]

# %%
# Opret af customer, trailer og booking test
print("-"*50)
customer = create_customer()
print(customer)
print("-"*50)
trailer = create_trailer()
print(trailer)
print("-"*50)
booking = create_booking(customer['id'], trailer['id'])
print(booking)
print("-"*50)
# Out:
# --------------------------------------------------
# {'id': 16, 'name': 'Svend CSharpsen', 'type': 'privat', 'phone': '12345678', 'address': 'Kundevej 1', 'email': 'kunde@example.com', 'bookings': None}
# --------------------------------------------------
# {'id': 17, 'name': 'zteffanos Test Trailer', 'year': 2023, 'brand': 'Zimula Trailerz', 'weight': 150, 'totalWeight': 750, 'carryWeight': 600, 'type': 'crypto', 'licensePlate': 'TT 12345', 'dayPrice': 200, 'length': 250, 'width': 125, 'bookings': None}
# --------------------------------------------------
# {'id': 10, 'bookedFrom': '2023-11-08T10:00:00', 'bookedTo': '2023-11-10T10:00:00', 'returned': False, 'paid': False, 'customerId': 16, 'trailerId': 17, 'customerData': None, 'trailerData': None}
# --------------------------------------------------

# %%
# Hent og print data fra tabellerne
fetch_and_print('customers')
fetch_and_print('trailers')
fetch_and_print('bookings')
# Out:
# Data from customers:
# [
#   {
#     "name": "Jensens V\u00e6rksted",
#     "type": "Erhverv",
#     "phone": "32123456",
#     "address": "Industrihaven 4, 4000 Roskilde",
#     "email": " jensensvaerksted@example.dk"
#   },
#   {
#     "name": "Hanne Fogh",
#     "type": "Privat",
#     "phone": "29768594",
#     "address": "B\u00f8gevej 7, 8000 Aarhus",
#     "email": " hanne.fogh@example.com"
#   },
#   {
#     "name": "S\u00f8ndergaard Biler",
#     "type": "Erhverv",
#     "phone": "31475869",
#     "address": "Autovej 12, 6700 Esbjerg",
#     "email": "info@sondergaardbiler.dk"
#   },
#   {
#     "name": "Larsen B\u00e5dudlejning",
#     "type": "Erhverv",
#     "phone": "33890001",
#     "address": "Havnepladsen 22, 1058 K\u00f8benhavn",
#     "email": "b\u00e5dudlejning@larsen.dk"
#   },
#   {
#     "name": "Kirstens Blomster",
#     "type": "Erhverv",
#     "phone": "35678900",
#     "address": "Blomsterv\u00e6nget 3, 2300 K\u00f8benhavn S",
#     "email": "kirstensblomster@example.dk"
#   },
#   {
#     "name": "Anders og Co.",
#     "type": "Privat",
#     "phone": "40203040",
#     "address": "Skovbrynet 1, 3400 Hiller\u00f8d",
#     "email": "andersogco@example.com"
#   },
#   {
#     "name": "Peters Cykler",
#     "type": "Erhverv",
#     "phone": "45678910",
#     "address": "Pedalvej 5, 7100 Vejle",
#     "email": "peterscykler@example.dk"
#   },
#   {
#     "name": "Mette's Catering",
#     "type": "Erhverv",
#     "phone": "50607080",
#     "address": "Kokkegade 8, 5000 Odense",
#     "email": "mettescatering@example.com"
#   },
#   {
#     "name": "Oliver Nielsen",
#     "type": "Privat",
#     "phone": "27395061",
#     "address": "Hyttevej 10, 2840 Holte",
#     "email": "oliver.nielsen@example.com"
#   },
#   {
#     "name": "Lise Lotte",
#     "type": "Private",
#     "phone": "50555055",
#     "address": "Flyttevejen 2, 6000 Kolding",
#     "email": "lise-lotte@koldingborger.dk"
#   },
#   {
#     "name": "Svend CSharpsen",
#     "type": "privat",
#     "phone": "12345678",
#     "address": "Kundevej 1",
#     "email": "kunde@example.com"
#   }
# ]
# Data from trailers:
# [
#   {
#     "name": "BRANFORD TRAILER 750KG",
#     "year": 2022,
#     "brand": "BRANFORD",
#     "weight": 110,
#     "totalWeight": 750,
#     "carryWeight": 640,
#     "type": "hobby",
#     "licensePlate": "TT 20800",
#     "dayPrice": 350,
#     "length": 195,
#     "width": 105
#   },
#   {
#     "name": "Nordisk Trailer Model 1000",
#     "year": 2021,
#     "brand": "Nordisk Trailer",
#     "weight": 130,
#     "totalWeight": 1000,
#     "carryWeight": 870,
#     "type": "bygge",
#     "licensePlate": "TT 20900",
#     "dayPrice": 400,
#     "length": 200,
#     "width": 120
#   },
#   {
#     "name": "Hermansen Cargo XL",
#     "year": 2020,
#     "brand": "Hermansen",
#     "weight": 160,
#     "totalWeight": 1300,
#     "carryWeight": 1140,
#     "type": "last",
#     "licensePlate": "TT 21000",
#     "dayPrice": 500,
#     "length": 250,
#     "width": 150
#   },
#   {
#     "name": "DanCargo Handyman",
#     "year": 2019,
#     "brand": "DanCargo",
#     "weight": 100,
#     "totalWeight": 600,
#     "carryWeight": 500,
#     "type": "hobby",
#     "licensePlate": "TT 21100",
#     "dayPrice": 300,
#     "length": 180,
#     "width": 90
#   },
#   {
#     "name": "Viking Trailers Strongman",
#     "year": 2018,
#     "brand": "Viking",
#     "weight": 145,
#     "totalWeight": 2000,
#     "carryWeight": 1855,
#     "type": "erhverv",
#     "licensePlate": "TT 21200",
#     "dayPrice": 700,
#     "length": 300,
#     "width": 160
#   },
#   {
#     "name": "Scandinavian Boat Carrier",
#     "year": 2022,
#     "brand": "Scandinavian",
#     "weight": 120,
#     "totalWeight": 1800,
#     "carryWeight": 1680,
#     "type": "b\u00e5d",
#     "licensePlate": "TT 21300",
#     "dayPrice": 600,
#     "length": 320,
#     "width": 180
#   },
#   {
#     "name": "\u00d8stergaard Multiuse XL",
#     "year": 2017,
#     "brand": "\u00d8stergaard",
#     "weight": 140,
#     "totalWeight": 750,
#     "carryWeight": 610,
#     "type": "multianvend",
#     "licensePlate": "TT 21400",
#     "dayPrice": 350,
#     "length": 195,
#     "width": 105
#   },
#   {
#     "name": "Carlsen Trailer Flexi",
#     "year": 2021,
#     "brand": "Carlsen",
#     "weight": 115,
#     "totalWeight": 825,
#     "carryWeight": 710,
#     "type": "universal",
#     "licensePlate": "TT 21500",
#     "dayPrice": 375,
#     "length": 190,
#     "width": 100
#   },
#   {
#     "name": "Haul Master Pro",
#     "year": 2019,
#     "brand": "Haul Master",
#     "weight": 150,
#     "totalWeight": 2500,
#     "carryWeight": 2350,
#     "type": "last",
#     "licensePlate": "TT 21600",
#     "dayPrice": 800,
#     "length": 340,
#     "width": 170
#   },
#   {
#     "name": "Dan Trailers Eco",
#     "year": 2023,
#     "brand": "Dan Trailers",
#     "weight": 90,
#     "totalWeight": 500,
#     "carryWeight": 410,
#     "type": "hobby",
#     "licensePlate": "TT 21700",
#     "dayPrice": 250,
#     "length": 160,
#     "width": 90
#   },
#   {
#     "name": "zteffanos Test Trailer",
#     "year": 2023,
#     "brand": "Zimula Trailerz",
#     "weight": 150,
#     "totalWeight": 750,
#     "carryWeight": 600,
#     "type": "crypto",
#     "licensePlate": "TT 12345",
#     "dayPrice": 200,
#     "length": 250,
#     "width": 125
#   }
# ]
# Data from bookings:
# [
#   {
#     "bookedFrom": "2023-10-01T08:00:00",
#     "bookedTo": "2023-10-03T18:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 1,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-05T09:00:00",
#     "bookedTo": "2023-10-10T15:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 2,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-12T14:00:00",
#     "bookedTo": "2023-10-15T12:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 3,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-18T10:00:00",
#     "bookedTo": "2023-10-25T16:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 4,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-27T08:30:00",
#     "bookedTo": "2023-10-29T19:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 5,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-01T12:00:00",
#     "bookedTo": "2023-11-04T14:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 6,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-05T08:00:00",
#     "bookedTo": "2023-11-12T20:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 7,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-06T13:00:00",
#     "bookedTo": "2023-11-10T11:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 8,
#     "trailerId": 2
#   },
#   {
#     "bookedFrom": "2023-11-08T10:00:00",
#     "bookedTo": "2023-11-10T10:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 16,
#     "trailerId": 17
#   }
# ]

# %%
# Slet bookingen, customeren og traileren
delete_resource('deletebooking', booking['id'])
delete_resource('deletecustomer', customer['id'])
delete_resource('deletetrailer', trailer['id'])
# Out:
# 204

# %%
# Bekræft sletningerne ved at hente data fra tabellerne igen
fetch_and_print('customers')
fetch_and_print('trailers')
fetch_and_print('bookings')
# Out:
# Data from customers:
# [
#   {
#     "name": "Jensens V\u00e6rksted",
#     "type": "Erhverv",
#     "phone": "32123456",
#     "address": "Industrihaven 4, 4000 Roskilde",
#     "email": " jensensvaerksted@example.dk"
#   },
#   {
#     "name": "Hanne Fogh",
#     "type": "Privat",
#     "phone": "29768594",
#     "address": "B\u00f8gevej 7, 8000 Aarhus",
#     "email": " hanne.fogh@example.com"
#   },
#   {
#     "name": "S\u00f8ndergaard Biler",
#     "type": "Erhverv",
#     "phone": "31475869",
#     "address": "Autovej 12, 6700 Esbjerg",
#     "email": "info@sondergaardbiler.dk"
#   },
#   {
#     "name": "Larsen B\u00e5dudlejning",
#     "type": "Erhverv",
#     "phone": "33890001",
#     "address": "Havnepladsen 22, 1058 K\u00f8benhavn",
#     "email": "b\u00e5dudlejning@larsen.dk"
#   },
#   {
#     "name": "Kirstens Blomster",
#     "type": "Erhverv",
#     "phone": "35678900",
#     "address": "Blomsterv\u00e6nget 3, 2300 K\u00f8benhavn S",
#     "email": "kirstensblomster@example.dk"
#   },
#   {
#     "name": "Anders og Co.",
#     "type": "Privat",
#     "phone": "40203040",
#     "address": "Skovbrynet 1, 3400 Hiller\u00f8d",
#     "email": "andersogco@example.com"
#   },
#   {
#     "name": "Peters Cykler",
#     "type": "Erhverv",
#     "phone": "45678910",
#     "address": "Pedalvej 5, 7100 Vejle",
#     "email": "peterscykler@example.dk"
#   },
#   {
#     "name": "Mette's Catering",
#     "type": "Erhverv",
#     "phone": "50607080",
#     "address": "Kokkegade 8, 5000 Odense",
#     "email": "mettescatering@example.com"
#   },
#   {
#     "name": "Oliver Nielsen",
#     "type": "Privat",
#     "phone": "27395061",
#     "address": "Hyttevej 10, 2840 Holte",
#     "email": "oliver.nielsen@example.com"
#   },
#   {
#     "name": "Lise Lotte",
#     "type": "Private",
#     "phone": "50555055",
#     "address": "Flyttevejen 2, 6000 Kolding",
#     "email": "lise-lotte@koldingborger.dk"
#   }
# ]
# Data from trailers:
# [
#   {
#     "name": "BRANFORD TRAILER 750KG",
#     "year": 2022,
#     "brand": "BRANFORD",
#     "weight": 110,
#     "totalWeight": 750,
#     "carryWeight": 640,
#     "type": "hobby",
#     "licensePlate": "TT 20800",
#     "dayPrice": 350,
#     "length": 195,
#     "width": 105
#   },
#   {
#     "name": "Nordisk Trailer Model 1000",
#     "year": 2021,
#     "brand": "Nordisk Trailer",
#     "weight": 130,
#     "totalWeight": 1000,
#     "carryWeight": 870,
#     "type": "bygge",
#     "licensePlate": "TT 20900",
#     "dayPrice": 400,
#     "length": 200,
#     "width": 120
#   },
#   {
#     "name": "Hermansen Cargo XL",
#     "year": 2020,
#     "brand": "Hermansen",
#     "weight": 160,
#     "totalWeight": 1300,
#     "carryWeight": 1140,
#     "type": "last",
#     "licensePlate": "TT 21000",
#     "dayPrice": 500,
#     "length": 250,
#     "width": 150
#   },
#   {
#     "name": "DanCargo Handyman",
#     "year": 2019,
#     "brand": "DanCargo",
#     "weight": 100,
#     "totalWeight": 600,
#     "carryWeight": 500,
#     "type": "hobby",
#     "licensePlate": "TT 21100",
#     "dayPrice": 300,
#     "length": 180,
#     "width": 90
#   },
#   {
#     "name": "Viking Trailers Strongman",
#     "year": 2018,
#     "brand": "Viking",
#     "weight": 145,
#     "totalWeight": 2000,
#     "carryWeight": 1855,
#     "type": "erhverv",
#     "licensePlate": "TT 21200",
#     "dayPrice": 700,
#     "length": 300,
#     "width": 160
#   },
#   {
#     "name": "Scandinavian Boat Carrier",
#     "year": 2022,
#     "brand": "Scandinavian",
#     "weight": 120,
#     "totalWeight": 1800,
#     "carryWeight": 1680,
#     "type": "b\u00e5d",
#     "licensePlate": "TT 21300",
#     "dayPrice": 600,
#     "length": 320,
#     "width": 180
#   },
#   {
#     "name": "\u00d8stergaard Multiuse XL",
#     "year": 2017,
#     "brand": "\u00d8stergaard",
#     "weight": 140,
#     "totalWeight": 750,
#     "carryWeight": 610,
#     "type": "multianvend",
#     "licensePlate": "TT 21400",
#     "dayPrice": 350,
#     "length": 195,
#     "width": 105
#   },
#   {
#     "name": "Carlsen Trailer Flexi",
#     "year": 2021,
#     "brand": "Carlsen",
#     "weight": 115,
#     "totalWeight": 825,
#     "carryWeight": 710,
#     "type": "universal",
#     "licensePlate": "TT 21500",
#     "dayPrice": 375,
#     "length": 190,
#     "width": 100
#   },
#   {
#     "name": "Haul Master Pro",
#     "year": 2019,
#     "brand": "Haul Master",
#     "weight": 150,
#     "totalWeight": 2500,
#     "carryWeight": 2350,
#     "type": "last",
#     "licensePlate": "TT 21600",
#     "dayPrice": 800,
#     "length": 340,
#     "width": 170
#   },
#   {
#     "name": "Dan Trailers Eco",
#     "year": 2023,
#     "brand": "Dan Trailers",
#     "weight": 90,
#     "totalWeight": 500,
#     "carryWeight": 410,
#     "type": "hobby",
#     "licensePlate": "TT 21700",
#     "dayPrice": 250,
#     "length": 160,
#     "width": 90
#   }
# ]
# Data from bookings:
# [
#   {
#     "bookedFrom": "2023-10-01T08:00:00",
#     "bookedTo": "2023-10-03T18:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 1,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-05T09:00:00",
#     "bookedTo": "2023-10-10T15:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 2,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-12T14:00:00",
#     "bookedTo": "2023-10-15T12:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 3,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-18T10:00:00",
#     "bookedTo": "2023-10-25T16:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 4,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-10-27T08:30:00",
#     "bookedTo": "2023-10-29T19:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 5,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-01T12:00:00",
#     "bookedTo": "2023-11-04T14:00:00",
#     "returned": true,
#     "paid": true,
#     "customerId": 6,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-05T08:00:00",
#     "bookedTo": "2023-11-12T20:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 7,
#     "trailerId": 1
#   },
#   {
#     "bookedFrom": "2023-11-06T13:00:00",
#     "bookedTo": "2023-11-10T11:00:00",
#     "returned": false,
#     "paid": false,
#     "customerId": 8,
#     "trailerId": 2
#   }
# ]
